# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.datasets import load_iris

# %%
iris=load_iris()
x=iris.data[:100,:2]
y=iris.target[:100]

# %%
weights=np.random.rand(2)
num_iteration=100
learning_rate=0.1

# %%
def activaition(x):
    return np.where(x>=0,1,0)

# %%
for i in range(num_iteration):
    gradient=np.zeros(2)
    cost=0
    for j in range(len(x)):
        output=activation(np.dot(x[j],weights))
        error=y[j]-output
        gradient+=error*x[j]
        cost+=error**2
    weights+=learning_rate*gradient
    print("Iterations: ",i,"Cost: ",cost)
# Out:
# Iterations:  0 Cost:  1
# Iterations:  1 Cost:  2
# Iterations:  2 Cost:  2
# Iterations:  3 Cost:  2
# Iterations:  4 Cost:  1
# Iterations:  5 Cost:  2
# Iterations:  6 Cost:  2
# Iterations:  7 Cost:  2
# Iterations:  8 Cost:  1
# Iterations:  9 Cost:  2
# Iterations:  10 Cost:  2
# Iterations:  11 Cost:  1
# Iterations:  12 Cost:  2
# Iterations:  13 Cost:  2
# Iterations:  14 Cost:  2
# Iterations:  15 Cost:  1
# Iterations:  16 Cost:  2
# Iterations:  17 Cost:  2
# Iterations:  18 Cost:  2
# Iterations:  19 Cost:  1
# Iterations:  20 Cost:  2
# Iterations:  21 Cost:  2
# Iterations:  22 Cost:  2
# Iterations:  23 Cost:  1
# Iterations:  24 Cost:  2
# Iterations:  25 Cost:  2
# Iterations:  26 Cost:  1
# Iterations:  27 Cost:  2
# Iterations:  28 Cost:  2
# Iterations:  29 Cost:  2
# Iterations:  30 Cost:  1
# Iterations:  31 Cost:  2
# Iterations:  32 Cost:  2
# Iterations:  33 Cost:  2
# Iterations:  34 Cost:  1
# Iterations:  35 Cost:  2
# Iterations:  36 Cost:  2
# Iterations:  37 Cost:  2
# Iterations:  38 Cost:  1
# Iterations:  39 Cost:  2
# Iterations:  40 Cost:  2
# Iterations:  41 Cost:  1
# Iterations:  42 Cost:  2
# Iterations:  43 Cost:  2
# Iterations:  44 Cost:  2
# Iterations:  45 Cost:  1
# Iterations:  46 Cost:  2
# Iterations:  47 Cost:  2
# Iterations:  48 Cost:  2
# Iterations:  49 Cost:  1
# Iterations:  50 Cost:  2
# Iterations:  51 Cost:  2
# Iterations:  52 Cost:  1
# Iterations:  53 Cost:  2
# Iterations:  54 Cost:  2
# Iterations:  55 Cost:  2
# Iterations:  56 Cost:  1
# Iterations:  57 Cost:  2
# Iterations:  58 Cost:  2
# Iterations:  59 Cost:  2
# Iterations:  60 Cost:  1
# Iterations:  61 Cost:  2
# Iterations:  62 Cost:  2
# Iterations:  63 Cost:  2
# Iterations:  64 Cost:  1
# Iterations:  65 Cost:  2
# Iterations:  66 Cost:  2
# Iterations:  67 Cost:  1
# Iterations:  68 Cost:  2
# Iterations:  69 Cost:  2
# Iterations:  70 Cost:  2
# Iterations:  71 Cost:  1
# Iterations:  72 Cost:  2
# Iterations:  73 Cost:  2
# Iterations:  74 Cost:  2
# Iterations:  75 Cost:  1
# Iterations:  76 Cost:  2
# Iterations:  77 Cost:  2
# Iterations:  78 Cost:  2
# Iterations:  79 Cost:  1
# Iterations:  80 Cost:  2
# Iterations:  81 Cost:  2
# Iterations:  82 Cost:  1
# Iterations:  83 Cost:  2
# Iterations:  84 Cost:  2
# Iterations:  85 Cost:  2
# Iterations:  86 Cost:  1
# Iterations:  87 Cost:  2
# Iterations:  88 Cost:  2
# Iterations:  89 Cost:  2
# Iterations:  90 Cost:  1
# Iterations:  91 Cost:  2
# Iterations:  92 Cost:  2
# Iterations:  93 Cost:  2
# Iterations:  94 Cost:  1
# Iterations:  95 Cost:  2
# Iterations:  96 Cost:  2
# Iterations:  97 Cost:  1
# Iterations:  98 Cost:  2
# Iterations:  99 Cost:  2

# %%
x_min,y_max=x[:,0].min()-1,x[:,0].max()+1
y_min,y_max=x[:,1].min()-1,x[:,1].max()+1
xx,yy=np.meshgrid(np.arange(x_min,x_max,0.1),np.arange(y_min,y_max,0.1))
z=activation(np.dot(np.c_[xx.ravel(),yy.ravel()],weights))
z=z.reshape(xx.shape)

# %%
plt.contourf(xx,yy,z,alpha=0.4)
plt.scatter(x[:,0],x[:,1],c=y,alpha=0.8)
plt.xlabel("Sepal LEngthh")
plt.ylabel("Sepal Width")
plt.title("Decision Boundary")
plt.show()

# %%
plt.contourf(xx,yy,z,alpha=0.4)
plt.scatter(x[:,0],x[:,1],c=y,alpha=0.8)
plt.xlabel("Petal Lenght")
plt.ylabel("Petal Width")
plt.title("Decision Boundary")
plt.show()
